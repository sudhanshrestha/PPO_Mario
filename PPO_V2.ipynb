# %%
import tensorflow as tf

# Check if GPU is available
if tf.test.gpu_device_name():
    print('GPU is available.')
else:
    print('No GPU is available.')
# Set GPU device
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# GPU is available.

# %%
import gym_super_mario_bros
from gym.spaces import Box
from gym import Wrapper
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT, COMPLEX_MOVEMENT, RIGHT_ONLY
import cv2
import numpy as np
import subprocess as sp

""" 
 Contains Monitor class to preorpcess and record
"""
class Monitor:
    def __init__(self, width, height, saved_path):

        self.command = ["ffmpeg", "-y", "-f", "rawvideo", "-vcodec", "rawvideo", "-s", "{}X{}".format(width, height),
                        "-pix_fmt", "rgb24", "-r", "60", "-i", "-", "-an", "-vcodec", "mpeg4", saved_path]
        try:
            self.pipe = sp.Popen(self.command, stdin=sp.PIPE, stderr=sp.PIPE)
        except FileNotFoundError:
            pass

    def record(self, image_array):
        try:
            self.pipe = sp.Popen(self.command, stdin=sp.PIPE, stderr=sp.PIPE)
        except FileNotFoundError as e:
            print(f"Error creating Monitor: {e}")



def process_frame(frame):
    if frame is not None:
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (84, 84))[None, :, :] / 255.
        return frame
    else:
        return np.zeros((1, 84, 84))


# class CustomReward(Wrapper):
#     def __init__(self, env=None, monitor=None):
#         super(CustomReward, self).__init__(env)
#         self.observation_space = Box(low=0, high=255, shape=(1, 84, 84))
#         self.curr_score = 0
#         if monitor:
#             self.monitor = monitor
#         else:
#             self.monitor = None

#     def step(self, action):
#         state, reward, done, info = self.env.step(action)
#         if self.monitor:
#             self.monitor.record(state)
#         state = process_frame(state)
#         reward += (info["score"] - self.curr_score) / 40.
#         self.curr_score = info["score"]
#         if done:
#             if info["flag_get"]:
#                 reward += 100
#             else:
#                 reward -= 50
#         return state, reward *0.05, done, info


class CustomReward(Wrapper):
    def __init__(self, env=None, monitor=None):
        super(CustomReward, self).__init__(env)
        self.observation_space = Box(low=0, high=255, shape=(1, 84, 84))
        self.prev_x_position = 0
        self.time_penalty = -0.01
        if monitor:
            self.monitor = monitor
        else:
            self.monitor = None

    def step(self, action):
        state, reward, done, info = self.env.step(action)
        if self.monitor:
            self.monitor.record(state)
        state = process_frame(state)
        # Calculate distance traveled (reward proportional to x-position increase)
        x_position = info["x_pos"]
        reward += (x_position - self.prev_x_position) * 0.1
        self.prev_x_position = x_position

        # Apply time penalty
        reward += self.time_penalty
        if done:
            if info["flag_get"]:
                reward += 100
            else:
                reward -= 50
        return state, reward *0.05, done, info
    
    def reset(self):
        self.prev_x_position = 0
        return process_frame(self.env.reset())

    # def reset(self):
    #     self.curr_score = 0
    #     return process_frame(self.env.reset())


class CustomSkipFrame(Wrapper):
    def __init__(self, env, skip=4):
        super(CustomSkipFrame, self).__init__(env)
        self.observation_space = Box(low=0, high=255, shape=(skip, 84, 84))
        self.skip = skip
        self.states = np.zeros((skip, 84, 84), dtype=np.float32)

    def step(self, action):
        total_reward = 0
        last_states = []
        for i in range(self.skip):
            state, reward, done, info = self.env.step(action)
            total_reward += reward
            if i >= self.skip /2:
                last_states.append(state)
            if done:
                self.reset()
                return self.states[None, :, :, :].astype(np.float32), total_reward, done, info
        max_state = np.max(np.concatenate(last_states,0), 0)
        self.states[:-1] = self.states[1:]
        self.states[-1] = max_state
        return self.states[None, :, :, :].astype(np.float32), total_reward, done, info


    def reset(self):
        state = self.env.reset()
        self.states = np.concatenate([state for _ in range(self.skip)], 0)
        return self.states[None, :, :, :].astype(np.float32)


def create_train_env(actions, output_path=None):
    env = gym_super_mario_bros.make("SuperMarioBros-1-1-v0")
    if output_path:
        monitor = Monitor(256, 240, output_path)
    else:
        monitor = None

    env = JoypadSpace(env, actions)
    env = CustomReward(env, monitor)
    env = CustomSkipFrame(env)
    return env


import torch.multiprocessing as mp

class MultipleEnvironments:
    def __init__(self, action_type, num_envs, output_path=None):
        self.agent_conns, self.env_conns = zip(*[mp.Pipe() for _ in range(num_envs)])
        if action_type == "right":
            actions = RIGHT_ONLY
            print("Action Right SET")
        elif action_type == "simple":
            actions = SIMPLE_MOVEMENT
            print("Action Simple Movements SET")
        else:
            actions = COMPLEX_MOVEMENT
            print("Action Complex SET")
        self.envs = [create_train_env(actions, output_path=output_path) for _ in range(num_envs)]
        print("sself env done")
        self.num_states = self.envs[0].observation_space.shape[0]
        print("sefl state done")
        self.num_actions = len(actions)
        print("Action done SET")
            
        for index in range(num_envs):
            print("Action: Startring process")
            process = mp.Process(target=self.run, args=(index,))
            print("Action: process IniI")
            process.start()
            print("Action: process almost done")
            self.env_conns[index].close()
        print("Environments created and processes started.")

    def run(self, index):
        self.agent_conns[index].close()
        while True:
            request, action = self.env_conns[index].recv()
            print(f"Environment {index} received request: {request}")
            if request == "step":
                print(f"Environment {index} is stepping with action: {action.item()}")
                self.env_conns[index].send(self.envs[index].step(action.item()))
            elif request == "reset":
                print(f"Environment {index} is resetting")
                self.env_conns[index].send(self.envs[index].reset())
            else:
                raise NotImplementedError

# %% [markdown]
# PPO Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, initializers

class PPO(tf.keras.Model):
    def __init__(self, num_inputs, num_actions):
        super(PPO, self).__init__()
        self.conv1 = tf.keras.layers.Conv2D(32, (3, 3), strides=2, padding='same', activation='relu', input_shape=num_inputs)
        self.conv2 = tf.keras.layers.Conv2D(32, (3, 3), strides=2, padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(32, (3, 3), strides=2, padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(32, (3, 3), strides=2, padding='same', activation='relu')
        self.flatten = tf.keras.layers.Flatten()
        self.linear = tf.keras.layers.Dense(512, activation='relu')
        self.critic_linear = tf.keras.layers.Dense(1)
        self.actor_linear = tf.keras.layers.Dense(num_actions)
        # No need for _initialize_weights method if using default initializations

    def call(self, inputs):
        x = tf.nn.relu(self.conv1(inputs))
        x = tf.nn.relu(self.conv2(x))
        x = tf.nn.relu(self.conv3(x))
        x = tf.nn.relu(self.conv4(x))
        x = self.flatten(x)
        x = tf.nn.relu(self.linear(x))
        actor_output = self.actor_linear(x)
        critic_output = self.critic_linear(x)
        return actor_output, critic_output

# %% [markdown]
# Train processes

# %%
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %%
# !python -m pip install tensorflow_probability==0.12.2

# %%
import warnings

# Suppress TensorFlow warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import timeit
from tensorboardX import SummaryWriter
import numpy as np
import tensorflow_probability as tfp

from collections import deque

# %%
# def eval(opt, global_model, num_states, num_actions):
#     tf.random.set_seed(123)
#     if opt.action_type == "right":
#         actions = RIGHT_ONLY
#     elif opt.action_type == "simple":
#         actions = SIMPLE_MOVEMENT
#     else:
#         actions = COMPLEX_MOVEMENT
#     env = create_train_env(actions=actions)
#     local_model = PPO(num_states, num_actions)
#     # local_model.evaluate()
#     state = tf.convert_to_tensor(env.reset())
#     done = True
#     curr_step = 0
#     actions = deque(maxlen=opt.max_actions)
#     while True:
#         curr_step +=1
#         if done:
#             local_model.set_weights(global_model.get_weights())
#             logits, value = local_model(state)
#             policy = tf.nn.softmax(logits, dim=1)
#             action = tf.argmax(policy).item()
#             state, reward, done, info = env.step(action)
#            # Uncomment following lines if you want to save model whenever level is completed
#             if info["flag_get"]:
#                 print("Finished")
#                 local_model.saved_model("{}/ppo_super_mario_bros_{".format(opt.saved_path,curr_step))

#             env.render()
#             actions.append(action)
#             if curr_step > opt.num_global_steps or actions.count(actions[0]) == actions.maxlen:
#                 done = True
#             if done:
#                 curr_step = 0
#                 actions.clear()
#                 state = env.reset()
#             state = tf.convert_to_tensor(state)

# %% [markdown]
# Running for 1000 EP

# %%
import os
os.environ['OMP_NUM_THREADS'] = '1'
from argparse import Namespace
import multiprocessing as _mp
import shutil
import tensorflow as tf
import warnings
from tensorflow.keras.mixed_precision import LossScaleOptimizer

# Suppress TensorFlow warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

def get_args():
    args = Namespace(
        action_type="COMPLEX_MOVEMENT",
        lr=0.00001,
        gamma=0.95,
        tau=1.0,
        beta=0.01,
        num_local_steps=100,
        num_processes=2,
        save_interval=250,
        # max_actions=200,
        log_path="tensorboard/a3c_super_mario_bros",
        saved_path="trained_models",
        load_from_previous_stage=False,
        num_epochs= 10,
        batch_size = 10,
        epsilon = 0.3,
        output_path = "output"
    )
    return args

# %%
# from tensorflow_probability import distributions as tfd

# %%
#  envs = create_train_env(actions=RIGHT_ONLY)
#  print(f"states : {envs.observation_space.shape}")
#  print(f"actions : {envs.action_space.n}")

# %%
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
consecutive_perfect_rewards = 0
consecutive_episodes_to_stop = 10
episode_list = []
total_steps_list = []
total_rewards_list = []
mean_rewards_list = []
total_loss_list = []

def train(opt, total_ep):
    print("INITIALIZING")
    tf.random.set_seed(123)
    print("SEED SET")
    if os.path.isdir(opt.log_path):
        shutil.rmtree(opt.log_path)
    os.makedirs(opt.log_path)
    if not os.path.isdir(opt.saved_path):
        os.makedirs(opt.saved_path)

    envs = create_train_env(actions=COMPLEX_MOVEMENT)
    print("ENV DONE")
    model = PPO(num_inputs=envs.observation_space.shape, num_actions=envs.action_space.n)
    print("PPO SET")
    model.build((None,) + envs.observation_space.shape)
    print("PPO BUILD")

    optimizer = tf.keras.optimizers.Adam(learning_rate=opt.lr)
    curr_states = envs.reset()

    curr_episode = 0
    current_total_rewards = 0

    print("Done initializing")
    
    # Set up ModelCheckpoint callback
    checkpoint_path = "{}/ppo_super_mario_bros_v2_checkpoint".format(opt.saved_path)
    model_checkpoint_callback = ModelCheckpoint(
        filepath=checkpoint_path,
        save_weights_only=False,
        save_best_only=True,  # Set to True if you only want to keep the best model
        monitor='total_rewards',  # Change 'total_rewards' to the metric you want to monitor
        mode='max',  # Adjust the mode based on the metric (e.g., 'max' for accuracy, 'min' for loss)
        verbose=1
    )
    # Initialize best_total_rewards before the training loop    
    best_total_rewards = float('-inf')
    while curr_episode < total_ep:
        curr_episode += 1
        total_steps = 0
        old_log_policies = []
        actions = []
        values = []
        states = []
        rewards = []
        dones = []


        for _ in range(opt.num_local_steps):
            total_steps +=1
            states.append(curr_states)
            logits, value = model(curr_states)
            values.append(tf.squeeze(value))
            policy = tf.nn.softmax(logits, axis=1)
            old_m = tfp.distributions.Categorical(probs=policy)
            action = old_m.sample()
            actions.append(action)
            old_log_policy = old_m.log_prob(action)
            old_log_policies.append(old_log_policy)
            
            # #!render 
            # envs.render()
            # display(plt.gcf())
            # clear_output(wait=True)

            state, reward, done, info = envs.step(action.numpy().item())
            rewards.append(reward)
            dones.append(done)
            curr_states = state
            # Update current_total_rewards after collecting rewards for the episode
        current_total_rewards = sum(rewards)
        if current_total_rewards > best_total_rewards:
            print(f"Saving model with best total_rewards: {current_total_rewards}")
            model.save("{}/ppo_super_mario_bros_v2".format(opt.saved_path), signatures=None)
            best_total_rewards = current_total_rewards
            current_total_rewards
            #!render
            # envs.render()
            # display(plt.gcf())
            # clear_output(wait=True)


        _, next_value = model(curr_states)
        next_value = tf.squeeze(next_value)
        old_log_policies = tf.concat(old_log_policies, axis=0)
        actions = tf.concat(actions, axis=0)
        values = tf.concat(values, axis=0)
        states = tf.concat(states, axis=0)

        
        gae = 0
        R = []

        # Calculate advantages and accumulate returns
        for value, reward, done in list(zip(values, rewards, dones))[::-1]:
            gae = gae * opt.gamma * opt.tau
            gae = gae + reward + opt.gamma * next_value * (1 - done) - value
            next_value = value
            R.append(gae + value)

        R = R[::-1]
        R = tf.concat(R, axis=0)
        advantages = R - values

        # PPO update loop
        for i in range(opt.num_epochs):
            indices = tf.random.shuffle(tf.range(opt.num_local_steps * opt.num_processes))
            for j in range(opt.batch_size):
                batch_indices = indices[
                    int(j * (opt.num_local_steps * opt.num_processes / opt.batch_size)): int((j + 1) * (
                            opt.num_local_steps * opt.num_processes / opt.batch_size))]

                # Gather states, actions, and old log policies using batch_indices
                batch_indices = tf.cast(batch_indices, dtype=tf.int32) #!
                batch_states = tf.gather(states, batch_indices)
                batch_actions = tf.gather(actions, batch_indices)
                batch_old_log_policies = tf.gather(old_log_policies, batch_indices)

                # Forward pass through the model
                with tf.GradientTape() as tape:
                    logits, value = model(batch_states)
                    new_policy = tf.nn.softmax(logits, axis=1)
                    new_m = tfp.distributions.Categorical(probs=new_policy)
                    new_log_policy = new_m.log_prob(batch_actions)

                    # PPO loss calculation
                    ratio = tf.exp(new_log_policy - batch_old_log_policies)
                    actor_loss = -tf.reduce_mean(tf.minimum(
                        ratio * tf.gather(advantages, batch_indices),
                        tf.clip_by_value(ratio, 1.0 - opt.epsilon, 1.0 + opt.epsilon) * tf.gather(advantages, batch_indices)
                    ))
                    R = tf.cast(R, dtype=tf.float32)
                    value = tf.cast(value, dtype=tf.float32)

                    critic_loss = tf.reduce_mean(tf.losses.mean_squared_error(R, value))
                    entropy_loss = tf.reduce_mean(new_m.entropy())
                    total_loss = actor_loss + critic_loss - opt.beta * entropy_loss

                # Optimization step
                gradients = tape.gradient(total_loss, model.trainable_variables)
                gradients, _ = tf.clip_by_global_norm(gradients, 0.5)
                optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        # Calculate metrics
        episode_list.append(curr_episode)
        total_steps_list.append(total_steps)
        total_rewards_list.append(sum(rewards))
        total_loss_list.append(total_loss)

        print("Episode: {}. Total Steps: {}. Total Rewards: {}. Total Loss: {}".format(
        curr_episode,
        total_steps,
        sum(rewards),
        total_loss
    ))
    # envs.close()



if __name__ == "__main__":
    opt = get_args()
    train(opt,total_ep=1000)
# Out:
# INITIALIZING
# SEED SET
# c:\Users\sudha\py10\lib\site-packages\gym\envs\registration.py:505: UserWarning: WARN: The environment SuperMarioBros-1-1-v0 is out of date. You should consider upgrading to version `v3` with the environment ID `SuperMarioBros-1-1-v3`.
#   logger.warn(
# ENV DONE
# PPO SET
# PPO BUILD
# Done initializing
# Saving model with best total_rewards: 8.790000000000001
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 1. Total Steps: 100. Total Rewards: 8.790000000000001. Total Loss: 3.340068817138672
# Episode: 2. Total Steps: 100. Total Rewards: -0.7599999999999999. Total Loss: 0.11948607861995697
# Episode: 3. Total Steps: 100. Total Rewards: 3.3100000000000023. Total Loss: 2.5452444553375244
# Episode: 4. Total Steps: 100. Total Rewards: -4.059999999999996. Total Loss: 1.3412781953811646
# Episode: 5. Total Steps: 100. Total Rewards: 0.23000000000000403. Total Loss: 0.5591002702713013
# Episode: 6. Total Steps: 100. Total Rewards: 1.8249999999999957. Total Loss: 2.900700807571411
# Episode: 7. Total Steps: 100. Total Rewards: 0.010000000000002077. Total Loss: 0.8663215637207031
# Episode: 8. Total Steps: 100. Total Rewards: -1.8149999999999988. Total Loss: 0.27480095624923706
# Saving model with best total_rewards: 12.380000000000003
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 9. Total Steps: 100. Total Rewards: 12.380000000000003. Total Loss: 4.0899271965026855
# Episode: 10. Total Steps: 100. Total Rewards: 5.730000000000002. Total Loss: 1.4747568368911743
# Episode: 11. Total Steps: 100. Total Rewards: -1.1999999999999997. Total Loss: 1.1253992319107056
# Episode: 12. Total Steps: 100. Total Rewards: -3.1250000000000004. Total Loss: 2.0202934741973877
# Episode: 13. Total Steps: 100. Total Rewards: -0.04499999999999989. Total Loss: 0.38798171281814575
# Episode: 14. Total Steps: 100. Total Rewards: -0.9800000000000001. Total Loss: 1.7358734607696533
# Episode: 15. Total Steps: 100. Total Rewards: -1.86. Total Loss: 0.3035227656364441
# Episode: 16. Total Steps: 100. Total Rewards: 0.06500000000000025. Total Loss: 0.16372999548912048
# Episode: 17. Total Steps: 100. Total Rewards: -1.9150000000000007. Total Loss: 0.2497340440750122
# Episode: 18. Total Steps: 100. Total Rewards: -0.32000000000000034. Total Loss: -0.015051556751132011
# Episode: 19. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.049535661935806274
# Episode: 20. Total Steps: 100. Total Rewards: -1.1999999999999995. Total Loss: 0.37460461258888245
# Episode: 21. Total Steps: 100. Total Rewards: 9.807. Total Loss: 3.784359931945801
# Saving model with best total_rewards: 19.535000000000004
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 22. Total Steps: 100. Total Rewards: 19.535000000000004. Total Loss: 2.840644121170044
# Saving model with best total_rewards: 29.74600000000002
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 23. Total Steps: 100. Total Rewards: 29.74600000000002. Total Loss: 14.830612182617188
# Episode: 24. Total Steps: 100. Total Rewards: 27.37500000000001. Total Loss: 10.762165069580078
# Episode: 25. Total Steps: 100. Total Rewards: 21.62500000000001. Total Loss: 11.407918930053711
# Episode: 26. Total Steps: 100. Total Rewards: 13.885. Total Loss: 12.446348190307617
# Episode: 27. Total Steps: 100. Total Rewards: 29.190999999999974. Total Loss: 14.307812690734863
# Episode: 28. Total Steps: 100. Total Rewards: 7.98499999999999. Total Loss: 6.063970565795898
# Episode: 29. Total Steps: 100. Total Rewards: -1.4750000000000003. Total Loss: 1.3206011056900024
# Episode: 30. Total Steps: 100. Total Rewards: -1.035. Total Loss: 0.49449068307876587
# Episode: 31. Total Steps: 100. Total Rewards: -2.2449999999999983. Total Loss: 0.6087355613708496
# Episode: 32. Total Steps: 100. Total Rewards: -1.5849999999999986. Total Loss: 0.65447598695755
# Episode: 33. Total Steps: 100. Total Rewards: -0.8150000000000011. Total Loss: -2.062879502773285e-05
# Episode: 34. Total Steps: 100. Total Rewards: -0.044999999999999804. Total Loss: 1.5555309057235718
# Episode: 35. Total Steps: 100. Total Rewards: -2.795000000000001. Total Loss: 0.3239861726760864
# Episode: 36. Total Steps: 100. Total Rewards: 0.39499999999999963. Total Loss: 0.16597676277160645
# Episode: 37. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.46077069640159607
# Episode: 38. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.0932328999042511
# Episode: 39. Total Steps: 100. Total Rewards: -1.2550000000000001. Total Loss: -0.002812149003148079
# Episode: 40. Total Steps: 100. Total Rewards: -3.840000000000001. Total Loss: 0.5132130980491638
# Episode: 41. Total Steps: 100. Total Rewards: 1.4400000000000062. Total Loss: 0.2969292998313904
# Episode: 42. Total Steps: 100. Total Rewards: 8.534999999999997. Total Loss: 3.797389507293701
# Episode: 43. Total Steps: 100. Total Rewards: 17.361000000000004. Total Loss: 8.878301620483398
# Episode: 44. Total Steps: 100. Total Rewards: 7.70999999999999. Total Loss: 4.540739059448242
# Episode: 45. Total Steps: 100. Total Rewards: 29.744999999999997. Total Loss: 16.956684112548828
# Episode: 46. Total Steps: 100. Total Rewards: 7.270000000000008. Total Loss: 4.589320659637451
# Episode: 47. Total Steps: 100. Total Rewards: -1.2550000000000003. Total Loss: 0.7781009674072266
# Episode: 48. Total Steps: 100. Total Rewards: -1.145000000000001. Total Loss: 0.37248775362968445
# Episode: 49. Total Steps: 100. Total Rewards: -2.1899999999999964. Total Loss: 0.8326517343521118
# Episode: 50. Total Steps: 100. Total Rewards: -1.0350000000000006. Total Loss: 0.3408028185367584
# Episode: 51. Total Steps: 100. Total Rewards: -0.7599999999999998. Total Loss: 0.0895480290055275
# Episode: 52. Total Steps: 100. Total Rewards: -0.8150000000000003. Total Loss: -0.037300340831279755
# Episode: 53. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.046631358563899994
# Episode: 54. Total Steps: 100. Total Rewards: -1.3100000000000003. Total Loss: -0.0016799401491880417
# Episode: 55. Total Steps: 100. Total Rewards: 5.321000000000002. Total Loss: 0.7876748442649841
# Episode: 56. Total Steps: 100. Total Rewards: 24.925000000000015. Total Loss: 13.415262222290039
# Episode: 57. Total Steps: 100. Total Rewards: 21.544999999999995. Total Loss: 15.660017967224121
# Episode: 58. Total Steps: 100. Total Rewards: 7.544999999999988. Total Loss: 4.402141094207764
# Episode: 59. Total Steps: 100. Total Rewards: 16.591000000000005. Total Loss: 5.104134559631348
# Saving model with best total_rewards: 30.09500000000001
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 60. Total Steps: 100. Total Rewards: 30.09500000000001. Total Loss: 14.84636116027832
# Episode: 61. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 3.644984006881714
# Episode: 62. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.745600700378418
# Episode: 63. Total Steps: 100. Total Rewards: -1.5850000000000009. Total Loss: 0.28841930627822876
# Episode: 64. Total Steps: 100. Total Rewards: -1.200000000000001. Total Loss: 0.5902112722396851
# Episode: 65. Total Steps: 100. Total Rewards: -1.9700000000000006. Total Loss: 0.17110121250152588
# Episode: 66. Total Steps: 100. Total Rewards: -0.15500000000000003. Total Loss: -0.05570501834154129
# Episode: 67. Total Steps: 100. Total Rewards: -1.5850000000000002. Total Loss: 0.04625842720270157
# Episode: 68. Total Steps: 100. Total Rewards: -0.7049999999999998. Total Loss: -0.006600828841328621
# Episode: 69. Total Steps: 100. Total Rewards: -1.2. Total Loss: 0.04442043974995613
# Episode: 70. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.15799982845783234
# Episode: 71. Total Steps: 100. Total Rewards: -1.2550000000000003. Total Loss: 0.00846099853515625
# Episode: 72. Total Steps: 100. Total Rewards: -1.1450000000000007. Total Loss: -0.015618618577718735
# Episode: 73. Total Steps: 100. Total Rewards: -1.2000000000000013. Total Loss: -0.04501502960920334
# Episode: 74. Total Steps: 100. Total Rewards: -1.2. Total Loss: 0.0006180889904499054
# Episode: 75. Total Steps: 100. Total Rewards: -0.7600000000000006. Total Loss: -0.04082360863685608
# Episode: 76. Total Steps: 100. Total Rewards: 29.895. Total Loss: 22.88226890563965
# Episode: 77. Total Steps: 100. Total Rewards: 16.785000000000007. Total Loss: 5.597010612487793
# Episode: 78. Total Steps: 100. Total Rewards: 8.42499999999998. Total Loss: 4.159867286682129
# Episode: 79. Total Steps: 100. Total Rewards: -1.1450000000000002. Total Loss: 1.0676429271697998
# Episode: 80. Total Steps: 100. Total Rewards: -1.7500000000000002. Total Loss: 0.3565293848514557
# Episode: 81. Total Steps: 100. Total Rewards: -1.3099999999999996. Total Loss: 0.44483307003974915
# Episode: 82. Total Steps: 100. Total Rewards: -2.3000000000000007. Total Loss: 0.38322344422340393
# Episode: 83. Total Steps: 100. Total Rewards: -0.54. Total Loss: 0.00795830599963665
# Episode: 84. Total Steps: 100. Total Rewards: -1.0900000000000003. Total Loss: 0.15858298540115356
# Episode: 85. Total Steps: 100. Total Rewards: -0.9249999999999996. Total Loss: 0.45430245995521545
# Episode: 86. Total Steps: 100. Total Rewards: -0.4849999999999999. Total Loss: 0.0940253734588623
# Episode: 87. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.0023398995399475098
# Episode: 88. Total Steps: 100. Total Rewards: -1.3099999999999998. Total Loss: 0.21523764729499817
# Episode: 89. Total Steps: 100. Total Rewards: -1.1450000000000005. Total Loss: -0.020657973363995552
# Episode: 90. Total Steps: 100. Total Rewards: -1.9699999999999998. Total Loss: 0.15868043899536133
# Episode: 91. Total Steps: 100. Total Rewards: -0.37500000000000006. Total Loss: -0.03663961589336395
# Episode: 92. Total Steps: 100. Total Rewards: -1.4750000000000005. Total Loss: -0.012126296758651733
# Episode: 93. Total Steps: 100. Total Rewards: -0.9250000000000005. Total Loss: -0.047360654920339584
# Episode: 94. Total Steps: 100. Total Rewards: -1.6950000000000003. Total Loss: 0.07812681794166565
# Episode: 95. Total Steps: 100. Total Rewards: 25.130500000000005. Total Loss: 20.135889053344727
# Episode: 96. Total Steps: 100. Total Rewards: 21.371999999999996. Total Loss: 8.690926551818848
# Saving model with best total_rewards: 31.065999999999992
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 97. Total Steps: 100. Total Rewards: 31.065999999999992. Total Loss: 13.547043800354004
# Episode: 98. Total Steps: 100. Total Rewards: 24.320000000000036. Total Loss: 10.490730285644531
# Episode: 99. Total Steps: 100. Total Rewards: 26.22000000000003. Total Loss: 17.455629348754883
# Episode: 100. Total Steps: 100. Total Rewards: 30.190000000000005. Total Loss: 15.685331344604492
# Episode: 101. Total Steps: 100. Total Rewards: 14.120999999999999. Total Loss: 13.916796684265137
# Episode: 102. Total Steps: 100. Total Rewards: 20.836000000000006. Total Loss: 4.37644624710083
# Saving model with best total_rewards: 32.92600000000002
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 103. Total Steps: 100. Total Rewards: 32.92600000000002. Total Loss: 4.334622383117676
# Episode: 104. Total Steps: 100. Total Rewards: 21.130000000000038. Total Loss: 4.412187099456787
# Episode: 105. Total Steps: 100. Total Rewards: 24.294999999999995. Total Loss: 10.166743278503418
# Episode: 106. Total Steps: 100. Total Rewards: 19.205. Total Loss: 4.027594566345215
# Episode: 107. Total Steps: 100. Total Rewards: 24.521. Total Loss: 3.0774037837982178
# Episode: 108. Total Steps: 100. Total Rewards: 22.560000000000016. Total Loss: 4.751276016235352
# Episode: 109. Total Steps: 100. Total Rewards: 10.735000000000012. Total Loss: 5.9246439933776855
# Episode: 110. Total Steps: 100. Total Rewards: 6.090000000000001. Total Loss: 7.5683135986328125
# Episode: 111. Total Steps: 100. Total Rewards: 26.795000000000034. Total Loss: 6.9082932472229
# Episode: 112. Total Steps: 100. Total Rewards: 27.75650000000003. Total Loss: 4.739362716674805
# Episode: 113. Total Steps: 100. Total Rewards: 26.465000000000003. Total Loss: 5.759238243103027
# Episode: 114. Total Steps: 100. Total Rewards: 24.210000000000015. Total Loss: 4.879209041595459
# Saving model with best total_rewards: 34.13200000000003
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 115. Total Steps: 100. Total Rewards: 34.13200000000003. Total Loss: 10.483033180236816
# Saving model with best total_rewards: 34.660000000000004
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 116. Total Steps: 100. Total Rewards: 34.660000000000004. Total Loss: 0.609365701675415
# Episode: 117. Total Steps: 100. Total Rewards: -0.37500000000000017. Total Loss: 13.472980499267578
# Episode: 118. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 6.934062957763672
# Episode: 119. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 3.8657443523406982
# Episode: 120. Total Steps: 100. Total Rewards: -1.6949999999999998. Total Loss: 3.023819923400879
# Episode: 121. Total Steps: 100. Total Rewards: -0.9249999999999995. Total Loss: 1.1461894512176514
# Episode: 122. Total Steps: 100. Total Rewards: -0.979999999999999. Total Loss: 1.434385895729065
# Episode: 123. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: -0.00818018801510334
# Episode: 124. Total Steps: 100. Total Rewards: 7.435000000000004. Total Loss: 3.851464033126831
# Episode: 125. Total Steps: 100. Total Rewards: 10.470000000000002. Total Loss: 3.1981966495513916
# Episode: 126. Total Steps: 100. Total Rewards: 29.20000000000001. Total Loss: 7.362642288208008
# Saving model with best total_rewards: 42.23100000000006
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 127. Total Steps: 100. Total Rewards: 42.23100000000006. Total Loss: 19.389488220214844
# Episode: 128. Total Steps: 100. Total Rewards: 35.69150000000002. Total Loss: 14.381404876708984
# Episode: 129. Total Steps: 100. Total Rewards: 30.626000000000012. Total Loss: 7.046847343444824
# Episode: 130. Total Steps: 100. Total Rewards: 26.300000000000004. Total Loss: 3.0945308208465576
# Episode: 131. Total Steps: 100. Total Rewards: 41.69150000000006. Total Loss: 9.562936782836914
# Episode: 132. Total Steps: 100. Total Rewards: 31.181000000000036. Total Loss: 9.848719596862793
# Episode: 133. Total Steps: 100. Total Rewards: 15.134999999999993. Total Loss: 6.120346546173096
# Episode: 134. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 7.840091705322266
# Episode: 135. Total Steps: 100. Total Rewards: -3.2350000000000003. Total Loss: 5.555517673492432
# Episode: 136. Total Steps: 100. Total Rewards: 1.385000000000004. Total Loss: 1.981808066368103
# Episode: 137. Total Steps: 100. Total Rewards: -1.8599999999999968. Total Loss: 1.4820936918258667
# Episode: 138. Total Steps: 100. Total Rewards: -1.145. Total Loss: 0.24255937337875366
# Episode: 139. Total Steps: 100. Total Rewards: -1.1450000000000002. Total Loss: 1.2313071489334106
# Episode: 140. Total Steps: 100. Total Rewards: -3.014999999999998. Total Loss: 0.6696499586105347
# Episode: 141. Total Steps: 100. Total Rewards: 0.2300000000000002. Total Loss: 0.10927470773458481
# Episode: 142. Total Steps: 100. Total Rewards: -0.815. Total Loss: -0.010684379376471043
# Episode: 143. Total Steps: 100. Total Rewards: -1.9700000000000009. Total Loss: 0.11794254928827286
# Episode: 144. Total Steps: 100. Total Rewards: 15.08. Total Loss: 10.051459312438965
# Episode: 145. Total Steps: 100. Total Rewards: 33.425500000000035. Total Loss: 17.102636337280273
# Episode: 146. Total Steps: 100. Total Rewards: 22.970999999999982. Total Loss: 7.973907947540283
# Episode: 147. Total Steps: 100. Total Rewards: 23.880000000000052. Total Loss: 8.712665557861328
# Episode: 148. Total Steps: 100. Total Rewards: 24.910999999999998. Total Loss: 6.670685291290283
# Episode: 149. Total Steps: 100. Total Rewards: 35.20000000000003. Total Loss: 2.1608755588531494
# Episode: 150. Total Steps: 100. Total Rewards: 9.524999999999983. Total Loss: 6.133094310760498
# Episode: 151. Total Steps: 100. Total Rewards: -1.0900000000000003. Total Loss: 6.616265773773193
# Episode: 152. Total Steps: 100. Total Rewards: -1.2000000000000008. Total Loss: 2.449025869369507
# Episode: 153. Total Steps: 100. Total Rewards: 8.479999999999995. Total Loss: 1.92727792263031
# Episode: 154. Total Steps: 100. Total Rewards: 17.130000000000003. Total Loss: 5.162776947021484
# Episode: 155. Total Steps: 100. Total Rewards: 26.611000000000008. Total Loss: 4.964479923248291
# Episode: 156. Total Steps: 100. Total Rewards: 7.87499999999999. Total Loss: 4.019039630889893
# Episode: 157. Total Steps: 100. Total Rewards: -1.0900000000000003. Total Loss: 2.8431639671325684
# Episode: 158. Total Steps: 100. Total Rewards: -1.3100000000000005. Total Loss: 1.095516562461853
# Episode: 159. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 0.15036600828170776
# Episode: 160. Total Steps: 100. Total Rewards: 4.440999999999994. Total Loss: 4.543605804443359
# Episode: 161. Total Steps: 100. Total Rewards: 16.290000000000013. Total Loss: 3.215902805328369
# Episode: 162. Total Steps: 100. Total Rewards: 18.87500000000003. Total Loss: 4.206089019775391
# Episode: 163. Total Steps: 100. Total Rewards: 31.499999999999982. Total Loss: 11.052582740783691
# Episode: 164. Total Steps: 100. Total Rewards: 30.955000000000023. Total Loss: 7.579502582550049
# Episode: 165. Total Steps: 100. Total Rewards: 11.67. Total Loss: 5.640893459320068
# Episode: 166. Total Steps: 100. Total Rewards: 9.061000000000002. Total Loss: 8.76308822631836
# Episode: 167. Total Steps: 100. Total Rewards: 27.106000000000048. Total Loss: 14.493292808532715
# Episode: 168. Total Steps: 100. Total Rewards: 13.660000000000014. Total Loss: 9.94823169708252
# Episode: 169. Total Steps: 100. Total Rewards: 32.275999999999996. Total Loss: 5.120326042175293
# Episode: 170. Total Steps: 100. Total Rewards: 14.584999999999987. Total Loss: 4.006448268890381
# Episode: 171. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 3.1130881309509277
# Episode: 172. Total Steps: 100. Total Rewards: -1.3100000000000003. Total Loss: 1.134453535079956
# Episode: 173. Total Steps: 100. Total Rewards: -1.0900000000000007. Total Loss: 0.36629030108451843
# Episode: 174. Total Steps: 100. Total Rewards: -1.254999999999999. Total Loss: 1.5733484029769897
# Episode: 175. Total Steps: 100. Total Rewards: -2.025. Total Loss: 0.16290293633937836
# Episode: 176. Total Steps: 100. Total Rewards: -0.7050000000000003. Total Loss: -0.00040375255048274994
# Episode: 177. Total Steps: 100. Total Rewards: -0.8150000000000004. Total Loss: -0.05727405473589897
# Episode: 178. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: -0.002523403614759445
# Episode: 179. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.005457930266857147
# Episode: 180. Total Steps: 100. Total Rewards: -1.3100000000000007. Total Loss: 0.00743483379483223
# Episode: 181. Total Steps: 100. Total Rewards: -1.0900000000000003. Total Loss: -0.03105483576655388
# Episode: 182. Total Steps: 100. Total Rewards: -1.2550000000000003. Total Loss: 0.002525411546230316
# Episode: 183. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: -0.025229450315237045
# Episode: 184. Total Steps: 100. Total Rewards: -1.145. Total Loss: 0.049966007471084595
# Episode: 185. Total Steps: 100. Total Rewards: -1.585000000000001. Total Loss: 0.05729225277900696
# Episode: 186. Total Steps: 100. Total Rewards: -1.5300000000000007. Total Loss: 0.024551797658205032
# Episode: 187. Total Steps: 100. Total Rewards: 20.275000000000002. Total Loss: 9.351712226867676
# Episode: 188. Total Steps: 100. Total Rewards: 23.55000000000002. Total Loss: 4.570784568786621
# Episode: 189. Total Steps: 100. Total Rewards: 5.785000000000012. Total Loss: 2.689582109451294
# Episode: 190. Total Steps: 100. Total Rewards: -1.1450000000000002. Total Loss: 1.417175054550171
# Episode: 191. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 0.34044671058654785
# Episode: 192. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.0029732566326856613
# Episode: 193. Total Steps: 100. Total Rewards: -1.2000000000000008. Total Loss: 0.017550012096762657
# Episode: 194. Total Steps: 100. Total Rewards: -1.1999999999999997. Total Loss: -0.03725173696875572
# Episode: 195. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: -0.023194119334220886
# Episode: 196. Total Steps: 100. Total Rewards: 2.54. Total Loss: -0.19119924306869507
# Episode: 197. Total Steps: 100. Total Rewards: 9.807000000000004. Total Loss: 2.534726858139038
# Episode: 198. Total Steps: 100. Total Rewards: 27.86699999999999. Total Loss: 3.098238468170166
# Episode: 199. Total Steps: 100. Total Rewards: 31.021000000000036. Total Loss: 7.2826924324035645
# Episode: 200. Total Steps: 100. Total Rewards: 15.52000000000001. Total Loss: 2.4505364894866943
# Episode: 201. Total Steps: 100. Total Rewards: 21.541000000000004. Total Loss: 15.048259735107422
# Episode: 202. Total Steps: 100. Total Rewards: 36.176000000000045. Total Loss: 11.319082260131836
# Episode: 203. Total Steps: 100. Total Rewards: 34.11000000000003. Total Loss: 2.007829189300537
# Episode: 204. Total Steps: 100. Total Rewards: 32.97700000000003. Total Loss: 13.133096694946289
# Episode: 205. Total Steps: 100. Total Rewards: 29.951. Total Loss: 5.996150970458984
# Episode: 206. Total Steps: 100. Total Rewards: 36.145000000000024. Total Loss: 3.0326154232025146
# Episode: 207. Total Steps: 100. Total Rewards: 15.245000000000006. Total Loss: 6.845118522644043
# Episode: 208. Total Steps: 100. Total Rewards: 32.11099999999999. Total Loss: 5.90962028503418
# Episode: 209. Total Steps: 100. Total Rewards: 33.314999999999976. Total Loss: 11.749824523925781
# Episode: 210. Total Steps: 100. Total Rewards: 15.464999999999993. Total Loss: 4.349544048309326
# Episode: 211. Total Steps: 100. Total Rewards: 28.415999999999993. Total Loss: 2.908691883087158
# Episode: 212. Total Steps: 100. Total Rewards: 24.95100000000002. Total Loss: 14.853090286254883
# Episode: 213. Total Steps: 100. Total Rewards: 33.944999999999965. Total Loss: 6.119752883911133
# Episode: 214. Total Steps: 100. Total Rewards: 31.671000000000028. Total Loss: 10.742647171020508
# Episode: 215. Total Steps: 100. Total Rewards: 38.40000000000001. Total Loss: 6.742489814758301
# Episode: 216. Total Steps: 100. Total Rewards: 35.365500000000026. Total Loss: 7.071270942687988
# Episode: 217. Total Steps: 100. Total Rewards: 17.855. Total Loss: 21.188650131225586
# Episode: 218. Total Steps: 100. Total Rewards: 18.435000000000013. Total Loss: 4.462880611419678
# Episode: 219. Total Steps: 100. Total Rewards: 8.48. Total Loss: 4.799118518829346
# Episode: 220. Total Steps: 100. Total Rewards: 20.671. Total Loss: 2.6526498794555664
# Episode: 221. Total Steps: 100. Total Rewards: 37.116. Total Loss: 4.154153823852539
# Saving model with best total_rewards: 47.035000000000004
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 222. Total Steps: 100. Total Rewards: 47.035000000000004. Total Loss: 2.255918025970459
# Episode: 223. Total Steps: 100. Total Rewards: 40.97650000000001. Total Loss: 12.094673156738281
# Episode: 224. Total Steps: 100. Total Rewards: 21.325000000000014. Total Loss: 15.262232780456543
# Episode: 225. Total Steps: 100. Total Rewards: 21.679999999999986. Total Loss: 2.166823387145996
# Episode: 226. Total Steps: 100. Total Rewards: 25.060999999999993. Total Loss: 15.426397323608398
# Episode: 227. Total Steps: 100. Total Rewards: 12.360000000000008. Total Loss: 11.930259704589844
# Episode: 228. Total Steps: 100. Total Rewards: 29.951000000000008. Total Loss: 5.14113187789917
# Episode: 229. Total Steps: 100. Total Rewards: 27.481999999999978. Total Loss: 9.073389053344727
# Episode: 230. Total Steps: 100. Total Rewards: 35.20999999999998. Total Loss: 6.600677490234375
# Episode: 231. Total Steps: 100. Total Rewards: -1.2550000000000006. Total Loss: 9.606176376342773
# Episode: 232. Total Steps: 100. Total Rewards: -1.1450000000000002. Total Loss: 3.6939303874969482
# Episode: 233. Total Steps: 100. Total Rewards: -1.3100000000000007. Total Loss: 0.7331944108009338
# Episode: 234. Total Steps: 100. Total Rewards: -1.309999999999999. Total Loss: 0.9433726072311401
# Episode: 235. Total Steps: 100. Total Rewards: -0.9800000000000003. Total Loss: 0.0008236449211835861
# Episode: 236. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.10667819529771805
# Episode: 237. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.004741773009300232
# Episode: 238. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.011342468671500683
# Episode: 239. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: -0.008400963619351387
# Episode: 240. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.032222963869571686
# Episode: 241. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.05274561792612076
# Episode: 242. Total Steps: 100. Total Rewards: 0.22999999999999982. Total Loss: 0.011375457048416138
# Episode: 243. Total Steps: 100. Total Rewards: 23.986000000000022. Total Loss: 6.200323581695557
# Episode: 244. Total Steps: 100. Total Rewards: 30.48000000000004. Total Loss: 10.125755310058594
# Episode: 245. Total Steps: 100. Total Rewards: 36.02000000000001. Total Loss: 8.806319236755371
# Episode: 246. Total Steps: 100. Total Rewards: 8.479999999999983. Total Loss: 5.912822246551514
# Episode: 247. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 3.7853469848632812
# Episode: 248. Total Steps: 100. Total Rewards: -1.2000000000000008. Total Loss: 0.7949903011322021
# Episode: 249. Total Steps: 100. Total Rewards: -1.4200000000000006. Total Loss: 0.052339740097522736
# Episode: 250. Total Steps: 100. Total Rewards: -0.9800000000000004. Total Loss: -0.06240669637918472
# Episode: 251. Total Steps: 100. Total Rewards: -1.2550000000000003. Total Loss: 0.00029868632555007935
# Episode: 252. Total Steps: 100. Total Rewards: -1.1450000000000005. Total Loss: -0.029295343905687332
# Episode: 253. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: -0.00563628226518631
# Episode: 254. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: -0.018662113696336746
# Episode: 255. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.022140566259622574
# Episode: 256. Total Steps: 100. Total Rewards: -4.665. Total Loss: 0.8539981842041016
# Episode: 257. Total Steps: 100. Total Rewards: 36.74099999999998. Total Loss: 41.65066909790039
# Episode: 258. Total Steps: 100. Total Rewards: 31.327000000000005. Total Loss: 9.167366981506348
# Episode: 259. Total Steps: 100. Total Rewards: 33.71100000000003. Total Loss: 9.885284423828125
# Episode: 260. Total Steps: 100. Total Rewards: 23.395999999999997. Total Loss: 16.111921310424805
# Episode: 261. Total Steps: 100. Total Rewards: 36.35000000000004. Total Loss: 5.978157997131348
# Episode: 262. Total Steps: 100. Total Rewards: 25.145000000000046. Total Loss: 2.7884268760681152
# Episode: 263. Total Steps: 100. Total Rewards: 8.48. Total Loss: 8.630245208740234
# Episode: 264. Total Steps: 100. Total Rewards: 9.010500000000002. Total Loss: 5.2523980140686035
# Episode: 265. Total Steps: 100. Total Rewards: 35.59500000000002. Total Loss: 9.959193229675293
# Episode: 266. Total Steps: 100. Total Rewards: 15.582000000000006. Total Loss: 10.667709350585938
# Episode: 267. Total Steps: 100. Total Rewards: 27.51000000000004. Total Loss: 7.1345109939575195
# Episode: 268. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 5.89279317855835
# Episode: 269. Total Steps: 100. Total Rewards: 33.816000000000024. Total Loss: 14.019425392150879
# Episode: 270. Total Steps: 100. Total Rewards: 5.840000000000013. Total Loss: 3.399993658065796
# Episode: 271. Total Steps: 100. Total Rewards: 8.479999999999972. Total Loss: 3.6707777976989746
# Episode: 272. Total Steps: 100. Total Rewards: 26.271000000000036. Total Loss: 17.562902450561523
# Episode: 273. Total Steps: 100. Total Rewards: 5.840000000000006. Total Loss: 3.458216905593872
# Episode: 274. Total Steps: 100. Total Rewards: 29.496000000000013. Total Loss: 10.445446014404297
# Episode: 275. Total Steps: 100. Total Rewards: 23.110000000000014. Total Loss: 3.1728992462158203
# Episode: 276. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 5.491469383239746
# Episode: 277. Total Steps: 100. Total Rewards: 8.355. Total Loss: 4.872815132141113
# Episode: 278. Total Steps: 100. Total Rewards: 35.870000000000026. Total Loss: 9.938677787780762
# Episode: 279. Total Steps: 100. Total Rewards: -0.8700000000000003. Total Loss: 4.30567741394043
# Episode: 280. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 1.1375831365585327
# Episode: 281. Total Steps: 100. Total Rewards: 17.485999999999997. Total Loss: 8.489129066467285
# Episode: 282. Total Steps: 100. Total Rewards: 21.844999999999995. Total Loss: 1.9154902696609497
# Episode: 283. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 3.534846067428589
# Episode: 284. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 1.0805383920669556
# Episode: 285. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 0.2599813938140869
# Episode: 286. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.035133183002471924
# Episode: 287. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: -0.012825308367609978
# Episode: 288. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 0.01641920767724514
# Episode: 289. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.019179701805114746
# Episode: 290. Total Steps: 100. Total Rewards: -1.2. Total Loss: -0.011752174235880375
# Episode: 291. Total Steps: 100. Total Rewards: -1.2. Total Loss: -0.02402682602405548
# Episode: 292. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.018402166664600372
# Episode: 293. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.015064738690853119
# Episode: 294. Total Steps: 100. Total Rewards: 8.479999999999997. Total Loss: 3.7373061180114746
# Episode: 295. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.5814903974533081
# Episode: 296. Total Steps: 100. Total Rewards: 26.220000000000006. Total Loss: 17.06722068786621
# Episode: 297. Total Steps: 100. Total Rewards: 23.681000000000033. Total Loss: 4.216160774230957
# Episode: 298. Total Steps: 100. Total Rewards: 35.420999999999964. Total Loss: 11.598820686340332
# Episode: 299. Total Steps: 100. Total Rewards: 8.479999999999967. Total Loss: 6.582919597625732
# Episode: 300. Total Steps: 100. Total Rewards: 26.270000000000017. Total Loss: 17.950801849365234
# Episode: 301. Total Steps: 100. Total Rewards: 31.791000000000036. Total Loss: 11.864293098449707
# Episode: 302. Total Steps: 100. Total Rewards: 22.780000000000047. Total Loss: 2.9682440757751465
# Episode: 303. Total Steps: 100. Total Rewards: 25.35099999999998. Total Loss: 11.157830238342285
# Episode: 304. Total Steps: 100. Total Rewards: 34.696000000000005. Total Loss: 7.1748857498168945
# Episode: 305. Total Steps: 100. Total Rewards: 38.385000000000005. Total Loss: 7.205695152282715
# Episode: 306. Total Steps: 100. Total Rewards: 27.23500000000003. Total Loss: 9.095856666564941
# Episode: 307. Total Steps: 100. Total Rewards: 26.270999999999994. Total Loss: 10.834691047668457
# Episode: 308. Total Steps: 100. Total Rewards: 5.840000000000009. Total Loss: 5.13668966293335
# Episode: 309. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 3.558669090270996
# Episode: 310. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.8505562543869019
# Episode: 311. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.1988653689622879
# Episode: 312. Total Steps: 100. Total Rewards: 7.874999999999991. Total Loss: 2.866877317428589
# Episode: 313. Total Steps: 100. Total Rewards: -0.5950000000000001. Total Loss: 0.6109544634819031
# Episode: 314. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.12158165872097015
# Episode: 315. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.035849086940288544
# Episode: 316. Total Steps: 100. Total Rewards: -1.3100000000000003. Total Loss: -0.004320081323385239
# Episode: 317. Total Steps: 100. Total Rewards: -1.0900000000000003. Total Loss: -0.017784899100661278
# Episode: 318. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.020970601588487625
# Episode: 319. Total Steps: 100. Total Rewards: 30.18550000000001. Total Loss: 27.327096939086914
# Episode: 320. Total Steps: 100. Total Rewards: 14.584999999999996. Total Loss: 2.3514456748962402
# Episode: 321. Total Steps: 100. Total Rewards: 16.894999999999992. Total Loss: 1.9139323234558105
# Episode: 322. Total Steps: 100. Total Rewards: 38.445999999999984. Total Loss: 3.0695385932922363
# Episode: 323. Total Steps: 100. Total Rewards: 32.940999999999995. Total Loss: 7.6455230712890625
# Episode: 324. Total Steps: 100. Total Rewards: 36.07500000000002. Total Loss: 5.453593730926514
# Episode: 325. Total Steps: 100. Total Rewards: 10.22000000000002. Total Loss: 9.898062705993652
# Episode: 326. Total Steps: 100. Total Rewards: 29.144999999999982. Total Loss: 0.7954903244972229
# Episode: 327. Total Steps: 100. Total Rewards: 42.56100000000006. Total Loss: 11.034332275390625
# Episode: 328. Total Steps: 100. Total Rewards: 35.255. Total Loss: 8.398648262023926
# Episode: 329. Total Steps: 100. Total Rewards: 5.840000000000018. Total Loss: 8.81716537475586
# Episode: 330. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 4.93890905380249
# Episode: 331. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 1.2076841592788696
# Episode: 332. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.18982809782028198
# Episode: 333. Total Steps: 100. Total Rewards: -1.8050000000000004. Total Loss: 0.08273834735155106
# Episode: 334. Total Steps: 100. Total Rewards: -0.7050000000000001. Total Loss: -0.016352485865354538
# Episode: 335. Total Steps: 100. Total Rewards: 2.650000000000001. Total Loss: 0.0592573881149292
# Episode: 336. Total Steps: 100. Total Rewards: 4.7400000000000135. Total Loss: 0.9226997494697571
# Episode: 337. Total Steps: 100. Total Rewards: -1.2. Total Loss: 0.396124005317688
# Episode: 338. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 0.04890899360179901
# Episode: 339. Total Steps: 100. Total Rewards: -1.3100000000000005. Total Loss: 0.01739230938255787
# Episode: 340. Total Steps: 100. Total Rewards: -1.09. Total Loss: 0.001565355807542801
# Episode: 341. Total Steps: 100. Total Rewards: -1.53. Total Loss: 0.054663628339767456
# Episode: 342. Total Steps: 100. Total Rewards: -0.87. Total Loss: 0.11239935457706451
# Episode: 343. Total Steps: 100. Total Rewards: 21.386500000000005. Total Loss: 8.98371410369873
# Episode: 344. Total Steps: 100. Total Rewards: 32.78999999999999. Total Loss: 6.231029033660889
# Episode: 345. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 5.511534690856934
# Episode: 346. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 1.4088844060897827
# Episode: 347. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.1594206988811493
# Episode: 348. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.013942154124379158
# Episode: 349. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: -0.03311258554458618
# Episode: 350. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.01699531264603138
# Episode: 351. Total Steps: 100. Total Rewards: -1.31. Total Loss: 0.015714673325419426
# Episode: 352. Total Steps: 100. Total Rewards: -1.0900000000000003. Total Loss: -0.04170607775449753
# Episode: 353. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.019289154559373856
# Episode: 354. Total Steps: 100. Total Rewards: 8.086. Total Loss: 3.8829736709594727
# Episode: 355. Total Steps: 100. Total Rewards: 28.721000000000004. Total Loss: 2.2568752765655518
# Episode: 356. Total Steps: 100. Total Rewards: 29.27000000000002. Total Loss: 4.542482376098633
# Episode: 357. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 6.8192877769470215
# Episode: 358. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 1.6648293733596802
# Episode: 359. Total Steps: 100. Total Rewards: -1.2550000000000006. Total Loss: 0.2590112090110779
# Episode: 360. Total Steps: 100. Total Rewards: -1.3100000000000003. Total Loss: 0.03167548030614853
# Episode: 361. Total Steps: 100. Total Rewards: -1.0350000000000004. Total Loss: -0.00355461984872818
# Episode: 362. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: -0.011570325121283531
# Episode: 363. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.014384900219738483
# Episode: 364. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: -0.01606157049536705
# Episode: 365. Total Steps: 100. Total Rewards: 8.479999999999997. Total Loss: 2.299133777618408
# Episode: 366. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 0.9555573463439941
# Episode: 367. Total Steps: 100. Total Rewards: 7.776000000000004. Total Loss: 3.460047960281372
# Episode: 368. Total Steps: 100. Total Rewards: 28.390000000000022. Total Loss: 10.727113723754883
# Episode: 369. Total Steps: 100. Total Rewards: 5.785000000000014. Total Loss: 3.353351593017578
# Episode: 370. Total Steps: 100. Total Rewards: -1.0900000000000005. Total Loss: 1.0407915115356445
# Episode: 371. Total Steps: 100. Total Rewards: 8.424999999999986. Total Loss: 3.051941156387329
# Episode: 372. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.41362133622169495
# Episode: 373. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: 0.0568571463227272
# Episode: 374. Total Steps: 100. Total Rewards: -1.2000000000000004. Total Loss: -0.0075109899044036865
# Episode: 375. Total Steps: 100. Total Rewards: -3.7299999999999995. Total Loss: 0.43252360820770264
# Episode: 376. Total Steps: 100. Total Rewards: 9.305000000000005. Total Loss: 2.0039894580841064
# Episode: 377. Total Steps: 100. Total Rewards: 31.39500000000004. Total Loss: 22.666706085205078
# Episode: 378. Total Steps: 100. Total Rewards: 5.015000000000001. Total Loss: 3.0155673027038574
# Episode: 379. Total Steps: 100. Total Rewards: 2.6500000000000004. Total Loss: 1.6460753679275513
# Episode: 380. Total Steps: 100. Total Rewards: 5.455000000000008. Total Loss: 1.4253404140472412
# Episode: 381. Total Steps: 100. Total Rewards: -1.3100000000000007. Total Loss: 0.2618275582790375
# Episode: 382. Total Steps: 100. Total Rewards: -1.0900000000000005. Total Loss: 0.0061135124415159225
# Episode: 383. Total Steps: 100. Total Rewards: -1.3100000000000007. Total Loss: 0.003544386476278305
# Episode: 384. Total Steps: 100. Total Rewards: -1.0900000000000007. Total Loss: -0.03213430196046829
# Episode: 385. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: -0.0350424088537693
# Episode: 386. Total Steps: 100. Total Rewards: 24.081500000000013. Total Loss: 12.438580513000488
# Episode: 387. Total Steps: 100. Total Rewards: 21.570000000000054. Total Loss: 13.594929695129395
# Episode: 388. Total Steps: 100. Total Rewards: 3.64. Total Loss: 3.624534845352173
# Episode: 389. Total Steps: 100. Total Rewards: 28.261000000000006. Total Loss: 7.191630840301514
# Episode: 390. Total Steps: 100. Total Rewards: 12.576000000000006. Total Loss: 5.774292469024658
# Episode: 391. Total Steps: 100. Total Rewards: 26.884999999999998. Total Loss: 4.516721725463867
# Episode: 392. Total Steps: 100. Total Rewards: 28.500000000000032. Total Loss: 4.670567989349365
# Episode: 393. Total Steps: 100. Total Rewards: 12.825000000000008. Total Loss: 6.643916606903076
# Episode: 394. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 2.60886287689209
# Episode: 395. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 0.8711286783218384
# Episode: 396. Total Steps: 100. Total Rewards: 24.135000000000005. Total Loss: 22.181596755981445
# Episode: 397. Total Steps: 100. Total Rewards: 29.270000000000003. Total Loss: 10.20413589477539
# Episode: 398. Total Steps: 100. Total Rewards: 5.9860000000000015. Total Loss: 3.252220630645752
# Episode: 399. Total Steps: 100. Total Rewards: 28.775000000000006. Total Loss: 5.1913299560546875
# Episode: 400. Total Steps: 100. Total Rewards: 0.44999999999999934. Total Loss: 2.102743625640869
# Episode: 401. Total Steps: 100. Total Rewards: -1.2000000000000002. Total Loss: 1.0626596212387085
# Episode: 402. Total Steps: 100. Total Rewards: -1.3650000000000004. Total Loss: 0.21521610021591187
# Episode: 403. Total Steps: 100. Total Rewards: 15.816000000000013. Total Loss: 7.091549396514893
# Episode: 404. Total Steps: 100. Total Rewards: 22.285000000000043. Total Loss: 8.292706489562988
# Episode: 405. Total Steps: 100. Total Rewards: 24.621000000000034. Total Loss: 3.5990991592407227
# Episode: 406. Total Steps: 100. Total Rewards: 13.800999999999995. Total Loss: 4.304304122924805
# Episode: 407. Total Steps: 100. Total Rewards: 34.49499999999998. Total Loss: 7.450876712799072
# Episode: 408. Total Steps: 100. Total Rewards: 17.036. Total Loss: 12.932255744934082
# Episode: 409. Total Steps: 100. Total Rewards: 15.024999999999988. Total Loss: 1.713901400566101
# Episode: 410. Total Steps: 100. Total Rewards: 8.47999999999999. Total Loss: 2.2633259296417236
# Episode: 411. Total Steps: 100. Total Rewards: 40.23750000000003. Total Loss: 20.078378677368164
# Episode: 412. Total Steps: 100. Total Rewards: 37.285. Total Loss: 3.9172115325927734
# Episode: 413. Total Steps: 100. Total Rewards: 37.54000000000003. Total Loss: 11.736154556274414
# Episode: 414. Total Steps: 100. Total Rewards: 32.88500000000001. Total Loss: 10.626047134399414
# Episode: 415. Total Steps: 100. Total Rewards: 37.896000000000015. Total Loss: 11.417608261108398
# Episode: 416. Total Steps: 100. Total Rewards: 34.935000000000024. Total Loss: 0.4608454704284668
# Episode: 417. Total Steps: 100. Total Rewards: 24.951000000000015. Total Loss: 20.842697143554688
# Episode: 418. Total Steps: 100. Total Rewards: 37.286. Total Loss: 6.802882194519043
# Episode: 419. Total Steps: 100. Total Rewards: 26.455999999999996. Total Loss: 7.6110005378723145
# Episode: 420. Total Steps: 100. Total Rewards: 36.28500000000003. Total Loss: 7.982654094696045
# Episode: 421. Total Steps: 100. Total Rewards: 17.83000000000002. Total Loss: 6.489756107330322
# Episode: 422. Total Steps: 100. Total Rewards: 20.715. Total Loss: 18.05164909362793
# Episode: 423. Total Steps: 100. Total Rewards: 21.075000000000017. Total Loss: 1.5417934656143188
# Episode: 424. Total Steps: 100. Total Rewards: -1.3100000000000005. Total Loss: 6.607280254364014
# Episode: 425. Total Steps: 100. Total Rewards: 20.15100000000002. Total Loss: 4.33768367767334
# Episode: 426. Total Steps: 100. Total Rewards: 35.47100000000005. Total Loss: 4.84821891784668
# Episode: 427. Total Steps: 100. Total Rewards: 26.08. Total Loss: 3.9005846977233887
# Episode: 428. Total Steps: 100. Total Rewards: 36.846. Total Loss: 6.448305606842041
# Episode: 429. Total Steps: 100. Total Rewards: 18.545000000000012. Total Loss: 5.966411113739014
# Episode: 430. Total Steps: 100. Total Rewards: 28.645999999999983. Total Loss: 6.839509963989258
# Episode: 431. Total Steps: 100. Total Rewards: 9.964999999999998. Total Loss: 4.962399959564209
# Episode: 432. Total Steps: 100. Total Rewards: 31.83099999999998. Total Loss: 4.4058637619018555
# Episode: 433. Total Steps: 100. Total Rewards: 18.709999999999997. Total Loss: 4.778200626373291
# Episode: 434. Total Steps: 100. Total Rewards: 22.600000000000023. Total Loss: 3.812997341156006
# Episode: 435. Total Steps: 100. Total Rewards: 24.81500000000006. Total Loss: 9.934996604919434
# Episode: 436. Total Steps: 100. Total Rewards: 16.345000000000013. Total Loss: 7.428559303283691
# Episode: 437. Total Steps: 100. Total Rewards: 39.20500000000002. Total Loss: 4.426283359527588
# Episode: 438. Total Steps: 100. Total Rewards: 23.935000000000027. Total Loss: 1.7475813627243042
# ...
# Episode: 840. Total Steps: 100. Total Rewards: 8.479999999999977. Total Loss: 4.433221340179443
# Episode: 841. Total Steps: 100. Total Rewards: -1.4200000000000004. Total Loss: 1.5250169038772583
# Episode: 842. Total Steps: 100. Total Rewards: 17.69100000000002. Total Loss: 3.3522701263427734
# Episode: 843. Total Steps: 100. Total Rewards: 14.639999999999981. Total Loss: 2.3789267539978027
# Episode: 844. Total Steps: 100. Total Rewards: 20.455. Total Loss: 5.6173624992370605
# Episode: 845. Total Steps: 100. Total Rewards: 17.995000000000054. Total Loss: 5.463090419769287
# Episode: 846. Total Steps: 100. Total Rewards: 33.311. Total Loss: 11.009787559509277
# Episode: 847. Total Steps: 100. Total Rewards: 23.044999999999984. Total Loss: 8.896796226501465
# Episode: 848. Total Steps: 100. Total Rewards: 26.08. Total Loss: 0.820559024810791
# Episode: 849. Total Steps: 100. Total Rewards: 10.625000000000004. Total Loss: 7.704977035522461
# Episode: 850. Total Steps: 100. Total Rewards: 41.961500000000015. Total Loss: 7.428523540496826
# Saving model with best total_rewards: 60.23500000000005
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# INFO:tensorflow:Assets written to: trained_models/ppo_super_mario_bros_v2\assets
# Episode: 851. Total Steps: 100. Total Rewards: 60.23500000000005. Total Loss: 17.58004379272461
# Episode: 852. Total Steps: 100. Total Rewards: 35.121000000000016. Total Loss: 26.094585418701172
# Episode: 853. Total Steps: 100. Total Rewards: 42.30500000000006. Total Loss: 1.3446646928787231
# Episode: 854. Total Steps: 100. Total Rewards: 31.515000000000015. Total Loss: 6.818317413330078
# Episode: 855. Total Steps: 100. Total Rewards: 33.17499999999997. Total Loss: 6.336103916168213
# Episode: 856. Total Steps: 100. Total Rewards: 25.77500000000001. Total Loss: 18.81035614013672
# Episode: 857. Total Steps: 100. Total Rewards: 24.581000000000028. Total Loss: 8.101564407348633
# Episode: 858. Total Steps: 100. Total Rewards: 35.54000000000001. Total Loss: 2.0957329273223877
# Episode: 859. Total Steps: 100. Total Rewards: 33.3455. Total Loss: 14.440522193908691
# Episode: 860. Total Steps: 100. Total Rewards: 32.69800000000003. Total Loss: 6.185563087463379
# Episode: 861. Total Steps: 100. Total Rewards: 18.16000000000006. Total Loss: 6.9569926261901855
# Episode: 862. Total Steps: 100. Total Rewards: 26.494999999999987. Total Loss: 4.343785285949707
# Episode: 863. Total Steps: 100. Total Rewards: 34.040000000000035. Total Loss: 5.656621932983398
# Episode: 864. Total Steps: 100. Total Rewards: 34.58100000000001. Total Loss: 7.51667594909668
# Episode: 865. Total Steps: 100. Total Rewards: 23.00000000000005. Total Loss: 5.5106892585754395
# Episode: 866. Total Steps: 100. Total Rewards: 18.435000000000006. Total Loss: 3.213724374771118
# Episode: 867. Total Steps: 100. Total Rewards: 41.36000000000001. Total Loss: 4.058892250061035
# Episode: 868. Total Steps: 100. Total Rewards: 26.190000000000033. Total Loss: 10.138859748840332
# Episode: 869. Total Steps: 100. Total Rewards: 39.685000000000024. Total Loss: 9.281193733215332
# Episode: 870. Total Steps: 100. Total Rewards: 25.475000000000037. Total Loss: 1.7900372743606567
# Episode: 871. Total Steps: 100. Total Rewards: 41.45600000000005. Total Loss: 15.919137001037598
# Episode: 872. Total Steps: 100. Total Rewards: 44.560000000000045. Total Loss: 1.8829450607299805
# Episode: 873. Total Steps: 100. Total Rewards: 19.77700000000001. Total Loss: 45.757057189941406
# Episode: 874. Total Steps: 100. Total Rewards: 31.876000000000026. Total Loss: 9.65237808227539
# Episode: 875. Total Steps: 100. Total Rewards: 38.72999999999998. Total Loss: 4.819743633270264
# Episode: 876. Total Steps: 100. Total Rewards: 37.11150000000003. Total Loss: 10.494119644165039
# Episode: 877. Total Steps: 100. Total Rewards: 26.49100000000002. Total Loss: 9.480441093444824
# Episode: 878. Total Steps: 100. Total Rewards: 24.37500000000003. Total Loss: 4.604383945465088
# Episode: 879. Total Steps: 100. Total Rewards: 11.88100000000002. Total Loss: 3.30340576171875
# Episode: 880. Total Steps: 100. Total Rewards: 34.93499999999998. Total Loss: 6.205686092376709
# Episode: 881. Total Steps: 100. Total Rewards: 8.479999999999976. Total Loss: 3.995852470397949
# Episode: 882. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 1.2162142992019653
# Episode: 883. Total Steps: 100. Total Rewards: 39.00500000000003. Total Loss: 22.712472915649414
# Episode: 884. Total Steps: 100. Total Rewards: 26.05600000000003. Total Loss: 3.5500447750091553
# Episode: 885. Total Steps: 100. Total Rewards: 28.774999999999984. Total Loss: 1.7044882774353027
# Episode: 886. Total Steps: 100. Total Rewards: 24.265000000000008. Total Loss: 7.260284900665283
# Episode: 887. Total Steps: 100. Total Rewards: 33.75600000000004. Total Loss: 17.528045654296875
# Episode: 888. Total Steps: 100. Total Rewards: 39.436000000000014. Total Loss: 7.9183454513549805
# Episode: 889. Total Steps: 100. Total Rewards: 27.39999999999999. Total Loss: 4.545844554901123
# Episode: 890. Total Steps: 100. Total Rewards: 50.210500000000046. Total Loss: 6.028845310211182
# Episode: 891. Total Steps: 100. Total Rewards: 24.256000000000007. Total Loss: 20.000057220458984
# Episode: 892. Total Steps: 100. Total Rewards: 14.639999999999977. Total Loss: 4.158880233764648
# Episode: 893. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 5.393739700317383
# Episode: 894. Total Steps: 100. Total Rewards: 23.130000000000027. Total Loss: 1.6382572650909424
# Episode: 895. Total Steps: 100. Total Rewards: 25.860000000000024. Total Loss: 7.412917137145996
# Episode: 896. Total Steps: 100. Total Rewards: 29.94650000000001. Total Loss: 8.935457229614258
# Episode: 897. Total Steps: 100. Total Rewards: 50.99500000000004. Total Loss: 12.90716552734375
# Episode: 898. Total Steps: 100. Total Rewards: 52.080000000000034. Total Loss: 6.8001909255981445
# Episode: 899. Total Steps: 100. Total Rewards: 32.87500000000003. Total Loss: 25.78144645690918
# Episode: 900. Total Steps: 100. Total Rewards: 22.944999999999986. Total Loss: 4.28677225112915
# Episode: 901. Total Steps: 100. Total Rewards: 26.90500000000002. Total Loss: 11.281429290771484
# Episode: 902. Total Steps: 100. Total Rewards: 33.9305. Total Loss: 4.043540954589844
# Episode: 903. Total Steps: 100. Total Rewards: 36.41000000000001. Total Loss: 8.201251029968262
# Episode: 904. Total Steps: 100. Total Rewards: 30.63500000000001. Total Loss: 7.106539249420166
# Episode: 905. Total Steps: 100. Total Rewards: 22.835000000000043. Total Loss: 9.198917388916016
# Episode: 906. Total Steps: 100. Total Rewards: 23.11. Total Loss: 1.165657877922058
# Episode: 907. Total Steps: 100. Total Rewards: 36.38100000000003. Total Loss: 14.037920951843262
# Episode: 908. Total Steps: 100. Total Rewards: 30.020000000000007. Total Loss: 12.927168846130371
# Episode: 909. Total Steps: 100. Total Rewards: 34.156. Total Loss: 4.249062538146973
# Episode: 910. Total Steps: 100. Total Rewards: 21.025000000000013. Total Loss: 9.682703971862793
# Episode: 911. Total Steps: 100. Total Rewards: 29.74500000000002. Total Loss: 3.9478960037231445
# Episode: 912. Total Steps: 100. Total Rewards: 36.87999999999998. Total Loss: 11.639303207397461
# Episode: 913. Total Steps: 100. Total Rewards: 29.160000000000043. Total Loss: 4.7183332443237305
# Episode: 914. Total Steps: 100. Total Rewards: 37.13500000000005. Total Loss: 6.832441806793213
# Episode: 915. Total Steps: 100. Total Rewards: 40.36050000000001. Total Loss: 10.808707237243652
# Episode: 916. Total Steps: 100. Total Rewards: 21.02. Total Loss: 6.068640232086182
# Episode: 917. Total Steps: 100. Total Rewards: 35.06150000000003. Total Loss: 7.840465545654297
# Episode: 918. Total Steps: 100. Total Rewards: 34.47600000000001. Total Loss: 9.814958572387695
# Episode: 919. Total Steps: 100. Total Rewards: 27.070000000000054. Total Loss: 10.265554428100586
# Episode: 920. Total Steps: 100. Total Rewards: 13.855999999999998. Total Loss: 11.3231782913208
# Episode: 921. Total Steps: 100. Total Rewards: 19.06500000000005. Total Loss: 8.090725898742676
# Episode: 922. Total Steps: 100. Total Rewards: 13.979999999999995. Total Loss: 4.275279998779297
# Episode: 923. Total Steps: 100. Total Rewards: 23.540000000000013. Total Loss: 2.796623945236206
# Episode: 924. Total Steps: 100. Total Rewards: 47.79050000000002. Total Loss: 7.043069839477539
# Episode: 925. Total Steps: 100. Total Rewards: 37.27150000000002. Total Loss: 9.055869102478027
# Episode: 926. Total Steps: 100. Total Rewards: 26.340000000000032. Total Loss: 10.9595365524292
# Episode: 927. Total Steps: 100. Total Rewards: 22.670000000000076. Total Loss: 10.440592765808105
# Episode: 928. Total Steps: 100. Total Rewards: 29.685499999999998. Total Loss: 3.656505823135376
# Episode: 929. Total Steps: 100. Total Rewards: 40.95100000000006. Total Loss: 12.405694007873535
# Episode: 930. Total Steps: 100. Total Rewards: 27.550999999999995. Total Loss: 12.546416282653809
# Episode: 931. Total Steps: 100. Total Rewards: 45.330000000000005. Total Loss: 10.750422477722168
# Episode: 932. Total Steps: 100. Total Rewards: 35.602. Total Loss: 15.88375186920166
# Episode: 933. Total Steps: 100. Total Rewards: 29.21500000000002. Total Loss: 3.979330062866211
# Episode: 934. Total Steps: 100. Total Rewards: 31.12050000000001. Total Loss: 5.258927345275879
# Episode: 935. Total Steps: 100. Total Rewards: 23.605000000000008. Total Loss: 1.7547805309295654
# Episode: 936. Total Steps: 100. Total Rewards: 35.81500000000002. Total Loss: 9.716638565063477
# Episode: 937. Total Steps: 100. Total Rewards: 43.436000000000014. Total Loss: 9.692230224609375
# Episode: 938. Total Steps: 100. Total Rewards: 45.48000000000001. Total Loss: 7.79607629776001
# Episode: 939. Total Steps: 100. Total Rewards: 33.70500000000001. Total Loss: 20.08315658569336
# Episode: 940. Total Steps: 100. Total Rewards: 21.68000000000001. Total Loss: 1.5612549781799316
# Episode: 941. Total Steps: 100. Total Rewards: 22.67000000000002. Total Loss: 10.2962646484375
# Episode: 942. Total Steps: 100. Total Rewards: 44.757500000000036. Total Loss: 7.176487922668457
# Episode: 943. Total Steps: 100. Total Rewards: 38.436000000000035. Total Loss: 8.952198028564453
# Episode: 944. Total Steps: 100. Total Rewards: 38.770000000000024. Total Loss: 6.937887668609619
# Episode: 945. Total Steps: 100. Total Rewards: 34.809999999999995. Total Loss: 4.7311320304870605
# Episode: 946. Total Steps: 100. Total Rewards: 42.296000000000035. Total Loss: 5.263591289520264
# Episode: 947. Total Steps: 100. Total Rewards: 32.280000000000015. Total Loss: 10.514230728149414
# Episode: 948. Total Steps: 100. Total Rewards: 31.02000000000002. Total Loss: 9.702237129211426
# Episode: 949. Total Steps: 100. Total Rewards: 39.28000000000004. Total Loss: 2.2324600219726562
# Episode: 950. Total Steps: 100. Total Rewards: 32.50499999999996. Total Loss: 6.861472129821777
# Episode: 951. Total Steps: 100. Total Rewards: 11.2. Total Loss: 12.187847137451172
# Episode: 952. Total Steps: 100. Total Rewards: 30.260000000000034. Total Loss: 7.515000820159912
# Episode: 953. Total Steps: 100. Total Rewards: 24.68550000000003. Total Loss: 9.515944480895996
# Episode: 954. Total Steps: 100. Total Rewards: 29.796000000000028. Total Loss: 18.055442810058594
# Episode: 955. Total Steps: 100. Total Rewards: 35.705000000000005. Total Loss: 1.970005989074707
# Episode: 956. Total Steps: 100. Total Rewards: 30.08500000000003. Total Loss: 4.639462471008301
# Episode: 957. Total Steps: 100. Total Rewards: 40.49000000000003. Total Loss: 1.7979686260223389
# Episode: 958. Total Steps: 100. Total Rewards: 40.086. Total Loss: 11.617667198181152
# Episode: 959. Total Steps: 100. Total Rewards: 40.23200000000004. Total Loss: 18.84528350830078
# Episode: 960. Total Steps: 100. Total Rewards: 32.605999999999995. Total Loss: 15.800835609436035
# Episode: 961. Total Steps: 100. Total Rewards: 15.771000000000006. Total Loss: 13.69732666015625
# Episode: 962. Total Steps: 100. Total Rewards: 33.17500000000002. Total Loss: 2.167649030685425
# Episode: 963. Total Steps: 100. Total Rewards: 35.79100000000001. Total Loss: 8.949877738952637
# Episode: 964. Total Steps: 100. Total Rewards: 33.93500000000003. Total Loss: 10.883726119995117
# Episode: 965. Total Steps: 100. Total Rewards: 36.383000000000024. Total Loss: 7.81704568862915
# Episode: 966. Total Steps: 100. Total Rewards: 29.050000000000043. Total Loss: 3.9411025047302246
# Episode: 967. Total Steps: 100. Total Rewards: 36.54000000000004. Total Loss: 12.331652641296387
# Episode: 968. Total Steps: 100. Total Rewards: 10.765000000000015. Total Loss: 23.15669059753418
# Episode: 969. Total Steps: 100. Total Rewards: 29.710000000000047. Total Loss: 11.41262435913086
# Episode: 970. Total Steps: 100. Total Rewards: 26.465000000000014. Total Loss: 5.325239181518555
# Episode: 971. Total Steps: 100. Total Rewards: 45.48050000000002. Total Loss: 7.5716753005981445
# Episode: 972. Total Steps: 100. Total Rewards: 24.845000000000002. Total Loss: 15.310248374938965
# Episode: 973. Total Steps: 100. Total Rewards: 28.045000000000023. Total Loss: 11.418025016784668
# Episode: 974. Total Steps: 100. Total Rewards: 45.631000000000014. Total Loss: 10.541037559509277
# Episode: 975. Total Steps: 100. Total Rewards: 29.296. Total Loss: 12.609796524047852
# Episode: 976. Total Steps: 100. Total Rewards: 22.340000000000035. Total Loss: 5.143411636352539
# Episode: 977. Total Steps: 100. Total Rewards: 18.566000000000006. Total Loss: 5.5010085105896
# Episode: 978. Total Steps: 100. Total Rewards: 30.42500000000006. Total Loss: 12.91331958770752
# Episode: 979. Total Steps: 100. Total Rewards: 0.0649999999999995. Total Loss: 9.266870498657227
# Episode: 980. Total Steps: 100. Total Rewards: 38.13600000000002. Total Loss: 17.105236053466797
# Episode: 981. Total Steps: 100. Total Rewards: 33.18200000000002. Total Loss: 8.638039588928223
# Episode: 982. Total Steps: 100. Total Rewards: 44.21500000000003. Total Loss: 11.208755493164062
# Episode: 983. Total Steps: 100. Total Rewards: 22.450000000000035. Total Loss: 4.182430744171143
# Episode: 984. Total Steps: 100. Total Rewards: 45.27500000000003. Total Loss: 12.052640914916992
# Episode: 985. Total Steps: 100. Total Rewards: 49.875000000000036. Total Loss: 9.537424087524414
# Episode: 986. Total Steps: 100. Total Rewards: 46.29500000000002. Total Loss: 14.641010284423828
# Episode: 987. Total Steps: 100. Total Rewards: 42.910000000000046. Total Loss: 2.7199606895446777
# Episode: 988. Total Steps: 100. Total Rewards: 30.326500000000024. Total Loss: 19.75100326538086
# Episode: 989. Total Steps: 100. Total Rewards: 14.144999999999987. Total Loss: 6.206182479858398
# Episode: 990. Total Steps: 100. Total Rewards: 32.72500000000002. Total Loss: 5.183749675750732
# Episode: 991. Total Steps: 100. Total Rewards: 31.945500000000038. Total Loss: 9.1245756149292
# Episode: 992. Total Steps: 100. Total Rewards: 34.370999999999995. Total Loss: 3.6752521991729736
# Episode: 993. Total Steps: 100. Total Rewards: 38.99000000000003. Total Loss: 9.501413345336914
# Episode: 994. Total Steps: 100. Total Rewards: 18.151. Total Loss: 20.498659133911133
# Episode: 995. Total Steps: 100. Total Rewards: 27.90699999999999. Total Loss: 8.09528636932373
# Episode: 996. Total Steps: 100. Total Rewards: 32.185000000000024. Total Loss: 8.197330474853516
# Episode: 997. Total Steps: 100. Total Rewards: 12.494999999999985. Total Loss: 5.007223606109619
# Episode: 998. Total Steps: 100. Total Rewards: -1.2000000000000006. Total Loss: 5.200021266937256
# Episode: 999. Total Steps: 100. Total Rewards: -2.0250000000000004. Total Loss: 1.4888441562652588
# Episode: 1000. Total Steps: 100. Total Rewards: 11.705000000000005. Total Loss: 1.7522485256195068

# %%
import matplotlib.pyplot as plt

# Plot Total Rewards
plt.figure(figsize=(8, 4))
plt.plot(episode_list, total_rewards_list, label='Total Rewards')
plt.title('Total Rewards over Episodes')
plt.xlabel('Episode')
plt.ylabel('Total Rewards')
plt.legend()
plt.show()



# Plot Total Loss
plt.figure(figsize=(8, 4))
plt.plot(episode_list, total_loss_list, label='Total Loss')
plt.title('Total Loss over Episodes')
plt.xlabel('Episode')
plt.ylabel('Total Loss')
plt.legend()
plt.show()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
from argparse import Namespace

# Import your environment creation function and PPO model definition here
# Assuming COMPLEX_MOVEMENT, create_train_env, and PPO are imported

def test_saved_model(opt):
    # Load the saved model
    loaded_model = tf.keras.models.load_model("{}/ppo_super_mario_bros_v2".format(opt.saved_path))

    # Create the environment
    env = create_train_env(actions=COMPLEX_MOVEMENT)
    state = env.reset()

    done = False
    total_reward = 0

    while not done:
        # Forward pass through the loaded model to get the action
        logits, _ = loaded_model(state)
        action = tf.argmax(tf.nn.softmax(logits, axis=1)).numpy().item()

        # Take the action in the environment
        state, reward, done, _ = env.step(action)

        # Accumulate total reward
        total_reward += reward

        # Render the environment (optional)
        env.render()
        display(plt.gcf())
        clear_output(wait=True)

    env.close()

    print(f"Total reward with the saved model: {total_reward}")
    return total_reward

if __name__ == "__main__":
    opt = get_args()

    # Test the saved model
    total_reward = test_saved_model(opt)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\conestoga_college\Semester 2\Reinforcement Learning\Code\Code\group_project\PPO\PPO_V2.ipynb Cell 23 line 4
#      <a href='vscode-notebook-cell:/e%3A/conestoga_college/Semester%202/Reinforcement%20Learning/Code/Code/group_project/PPO/PPO_V2.ipynb#X33sZmlsZQ%3D%3D?line=43'>44</a> opt = get_args()
#      <a href='vscode-notebook-cell:/e%3A/conestoga_college/Semester%202/Reinforcement%20Learning/Code/Code/group_project/PPO/PPO_V2.ipynb#X33sZmlsZQ%3D%3D?line=45'>46</a> # Render games with the best model
# ---> <a href='vscode-notebook-cell:/e%3A/conestoga_college/Semester%202/Reinforcement%20Learning/Code/Code/group_project/PPO/PPO_V2.ipynb#X33sZmlsZQ%3D%3D?line=46'>47</a> render_best_model(opt)
#
# e:\conestoga_college\Semester 2\Reinforcement Learning\Code\Code\group_project\PPO\PPO_V2.ipynb Cell 23 line 1
#      <a href='vscode-notebook-cell:/e%3A/conestoga_college/Semester%202/Reinforcement%20Learning/Code/Code/group_project/PPO/PPO_V2.ipynb#X33sZmlsZQ%3D%3D?line=13'>14</a> loaded_model = tf.keras.models.load_model("{}/ppo_super_mario_bros_v2".format(opt.saved_path))
#      <a href='vscode-notebook-cell:/e%3A/conestoga_college/Semester%202/Reinforcement%20Learning/Code/Code/group_project/PPO/PPO_V2.ipynb#X33sZmlsZQ%3D%3D?line=15'>16</a> # Create the environment
# ---> <a href='vscode-notebook-cell:/e%3A/conestoga_college/Semester%202/Reinforcement%20Learning/Code/Code/group_project/PPO/PPO_V2.ipynb#X33sZmlsZQ%3D%3D?line=16'>17</a> env = create_train_env(actions=COMPLEX_MOVEMENT)
#      <a href='vscode-notebook-cell:/e%3A/conestoga_college/Semester%202/Reinforcement%20Learning/Code/Code/group_project/PPO/PPO_V2.ipynb#X33sZmlsZQ%3D%3D?line=17'>18</a> state = env.reset()
#      <a href='vscode-notebook-cell:/e%3A/conestoga_college/Semester%202/Reinforcement%20Learning/Code/Code/group_project/PPO/PPO_V2.ipynb#X33sZmlsZQ%3D%3D?line=19'>20</a> done = False
#
# NameError: name 'create_train_env' is not defined
